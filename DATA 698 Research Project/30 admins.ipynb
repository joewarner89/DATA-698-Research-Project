# %%
import pandas as pd

# Load files
diagnoses = pd.read_csv(r"ADMISSIONS (2).csv")
icd_lookup = pd.read_csv(r"C:\Users\Warner_Beast\OneDrive\Documents\CUNY\DATA 698\Data\Manual\icd-9-comparison-excel-file.csv")

# Inspect columns
print("Diagnoses columns:", diagnoses.columns.tolist())
print("ICD lookup columns:", icd_lookup.columns.tolist())
# Out:
# Diagnoses columns: ['ROW_ID', 'SUBJECT_ID', 'HADM_ID', 'ADMITTIME', 'DISCHTIME', 'DEATHTIME', 'ADMISSION_TYPE', 'ADMISSION_LOCATION', 'DISCHARGE_LOCATION', 'INSURANCE', 'LANGUAGE', 'RELIGION', 'MARITAL_STATUS', 'ETHNICITY', 'EDREGTIME', 'EDOUTTIME', 'DIAGNOSIS', 'HOSPITAL_EXPIRE_FLAG', 'HAS_CHARTEVENTS_DATA']
# ICD lookup columns: ['ICD9', 'Description', 'HCUP CCS Classification', 'HCC Category', 'CCW Classification', 'CDPS Classification']
